# %%
import xarray as xr

# %%
shot = xr.open_datatree(
    "https://s3.echo.stfc.ac.uk/mast/level2/shots/15585.zarr",
    engine="zarr",
    chunks="auto",
)
shot
# Out:
# <xarray.DataTree>
# Group: /
# ├── Group: /equilibrium
# │       Dimensions:              (time: 115, z: 65, major_radius: 65,
# │                                 n_boundary_coords: 157, profile_r: 65, n_x_points: 4)
# │       Coordinates:
# │         * major_radius         (major_radius) float64 520B 0.06 0.09 ... 1.95 1.98
# │         * n_boundary_coords    (n_boundary_coords) float32 628B 0.0 1.0 ... 156.0
# │         * n_x_points           (n_x_points) <U16 256B 'EFM_XPOINT1_R(C)' ... 'EFM_X...
# │         * profile_r            (profile_r) float32 260B 0.0 0.01562 ... 0.9844 1.0
# │         * time                 (time) float64 920B -0.0656 -0.0606 ... 0.4994 0.5044
# │         * z                    (z) float32 260B -2.0 -1.938 -1.875 ... 1.875 1.938 2.0
# │       Data variables: (12/35)
# │           beta_normal          (time) float64 920B dask.array<chunksize=(115,), meta=np.ndarray>
# ...

# %%
eq = xr.open_zarr(
    "https://s3.echo.stfc.ac.uk/mast/level2/shots/15585.zarr",
    group="equilibrium",
)
psi = eq["psi"].dropna("time").transpose("time", ...)

# %%
eq = eq.interp({"time": psi["time"]}).interp({"major_radius": psi["major_radius"]})
